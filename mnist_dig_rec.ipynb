# %% [markdown]
# # MNIST dataset for digit classification
# ## mnist database consists of 28x28 pixel greyscale image

# %% [markdown]
# ![mnist.png](attachment:mnist.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random,copy,math

# %%
# enter the parameters by running this cell
num_layers = int(input("Enter the number of layers >>>"))
num_nodes = []
num_activation = []
for x in range(1,num_layers+1):
    y = input(f"enter no. of nodes in layer-{x}    >>>")
    num_nodes.append(y)
    print(f""" choose the activation function for layer-{x}
               1--> relu
               2--> tanh
               3--> sigmoid
               4--> softmax""")
    y = input(f"enter the activation function for layer-{x}    >>>")
    num_activation.append(y)

# %%
# Out:
# ['784', '100', '50', '100', '10'] 5 ['1', '1', '1', '1', '4']
